# %% [markdown]
# ### 인트로
# - seaborn.objects 는 seaborn plot을 만들기 위한 완전히 새로운 인터페이스로 버전 0.12에 도입되었다.
# - 데이터 변환 및 플로팅을 위한 구성 가능한 클래스 모음으로 구성된 보다 일관되고 유연한 API를 제공한다.
# - 기존 기능과 달리 seaborn 새 인터페이스는 matplotlib로 드롭다운하지 않고 종단 간 플롯 사양 및 사용자 지정을 지원하는 것을 목표로 한다.

# %% [markdown]
# ## 플롯 지정 및 데이터 매핑
# - 개체 인터페이스는 다음 규칙에 따라 가져와야한다.
# - 네임 seaborn.objects 스페이스는 모든 관련 클래스에 대한 엑세스를 제공한다.
# - 가장 중요한 것은 plot. 개체를 인스턴스화하고 해당 매서드를 호출하여 플롯을 지정한다.
# - 객체와 인스턴스화 내용 참고 자료 : https://blog.naver.com/hhw1990/221360695920

# %%
import seaborn as sns

# %%
import seaborn.objects as so

# %%
penguins = sns.load_dataset('penguins')

# %%
(
    so.Plot(penguins, x="bill_length_mm", y="bill_depth_mm")
    .add(so.Dot())
)

# %% [markdown]
# 산점도를 생성하는 이 코드는 꽤 친숙하게 보일 것입니다. seaborn.scatterplot()를 사용할 때와 마찬가지로 깔끔한 데이터 프레임을 전달하고 해당 열 중 두 개를 플롯의 x및 y좌표에 할당했습니다. 그러나 차트 유형으로 시작한 다음 일부 데이터 할당을 추가하는 대신 여기서는 데이터 할당으로 시작한 다음 그래픽 요소를 추가했습니다.

# %% [markdown]
# # 속성 설정
# - 클래스는 데이터 값을 그래픽으로 나타내는 개체 Dot의 예이다
# - Mark의 각 모양을 변경하기 위해 설정할 수 있는 여러 속성이 있다.

# %%
  so.Plot(penguins, x="bill_length_mm",
          y="bill_depth_mm").add(so.Dot(color="g", pointsize=4))

# %% [markdown]
# # 매핑 속성
# seaborn의 기능과 마찬가지로 데이터 값을 다양한 그래픽 속성에 매핑하는 것도 가능하다
